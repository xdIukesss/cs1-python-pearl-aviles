# %% [markdown]
# <a href="https://colab.research.google.com/github/xdIukesss/cs1-python-pearl-aviles/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
num3 = int(input("Enter third number"))

if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3

print(f"The largest number is {largest}")
# Out:
# Enter first number39
# Enter second number21
# Enter third number38
# The largest number is 39
