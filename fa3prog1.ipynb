# %% [markdown]
# <a href="https://colab.research.google.com/github/xdIukesss/cs1-python-pearl-aviles/blob/main/fa3prog1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter student's name: ")
age = input("Enter student's age: ")
course = input("Enter student's course: ")

print("\n--- Student Information ---")
print("Name:", name)
print("Age:", age)
print("Course:", course)
# Out:
# Enter student's name: lucas
# Enter student's age: 13
# Enter student's course: adtech
#
# --- Student Information ---
# Name: lucas
# Age: 13
# Course: adtech
