# %% [markdown]
# <a href="https://colab.research.google.com/github/xdIukesss/cs1-python-pearl-aviles/blob/main/fa3prog2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
score = float(input("Enter exam score: "))

if score >= 75:
    print("Passed")
else:
    print("Failed")
